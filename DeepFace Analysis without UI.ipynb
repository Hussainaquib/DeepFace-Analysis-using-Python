# %%
pip install deepface
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
img1=cv2.imread("C:/Users/91975/OneDrive/Pictures/Screenshots/Screenshot 2023-08-15 123410.png")
plt.imshow(img1[:,:,::-1])
plt.show()

# %%
#Age prediction
result=DeepFace.analyze(img1,actions=['age'])
print("Predicted Age is:", result[0]['age'])
# Out:
# Action: age: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
# Predicted Age is: 26

# %%
#Gender prediction
result = DeepFace.analyze(img1, actions=['gender'])
print("Predicted Gender is:", result[0]['gender'])
# Out:
# Action: gender: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
# Predicted Gender is: {'Woman': 0.04848072421737015, 'Man': 99.9515175819397}

# %%
#Emotion Detection
result = DeepFace.analyze(img1, actions=['emotion'])
print("Predicted Emotion is:", result[0]['dominant_emotion'])
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 10.10it/s]
# Predicted Emotion is: angry

# %%
#Facial Expression recognition
result = DeepFace.analyze(img1, actions=['emotion'])
print("Predicted Expression is:", result[0]['dominant_emotion'])
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.27it/s]
# Predicted Expression is: happy

# %%
#Predicted Race/Ethnicity
result = DeepFace.analyze(img1, actions=['race'])
print("Predicted Race/Ethnicity is:", result[0]['dominant_race'])
# Out:
# Action: race: 100%|██████████| 1/1 [00:01<00:00,  1.02s/it]
# Predicted Race/Ethnicity is: indian

# %%
img2=cv2.imread("C:/Users/91975/OneDrive/Pictures/Screenshots/Screenshot 2023-05-30 005223.png")
plt.imshow(img2[:,:,::-1])
plt.show()

# %%
img3=cv2.imread("C:/Users/91975/OneDrive/Pictures/Screenshots/Screenshot 2023-05-30 005303.png")
plt.imshow(img3[:,:,::-1])
plt.show()

# %%
#Face Recognition: Check img2 and img3 are same or not
result = DeepFace.verify("C:/Users/91975/OneDrive/Pictures/Screenshots/Screenshot 2023-05-30 005223.png", "C:/Users/91975/OneDrive/Pictures/Screenshots/Screenshot 2023-05-30 005303.png")
print("Are the faces the same person?", result['verified'])
# Out:
# Are the faces the same person? False
